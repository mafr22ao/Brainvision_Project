# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = np.load('./Optical_flowarrays/batch_0_Optical_Flow_Data.npz', allow_pickle=True)

# %%
print(data.files)
# Out:
# ['File_ID', 'Data']

# %%
np.array(data['Data'][0]).shape
# Out:
# (89, 268, 268, 2)

# %%
# Creating the bar chart
plt.figure(figsize=(10, 6))
plt.bar(File_ID, Avg_flow)
plt.xlabel('Video')
plt.ylabel('Avg Optical Flow Magnitude')
plt.title('Comparison of Motion Across Videos')
plt.xticks(rotation=45)  # Rotate labels for better readability if needed
plt.show()

# %%
data_2 = np.load('./Optical_flowarrays/batch_0_Maximum_Flow.npz', allow_pickle=True)

# %%
print(data_2.files)
# Out:
# ['File_ID', 'Data']

# %%
File_ID_max = data_2['File_ID']
Avg_flow = data['Data']

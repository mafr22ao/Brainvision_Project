# %%
video_folder = "AlgonautsVideos268_All_30fpsmax"

# %%
import os
import gc
import cv2
import numpy as np
import sys
import pickle
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.preprocessing import image
from keras.models import Model
import contextlib

# %%
base_model = ResNet50(weights='imagenet', include_top=False)

# Select layers for feature extraction at the end of each stage
layers_to_extract = {

    'stage_2_conv': base_model.get_layer('conv2_block3_3_conv').output,
    'stage_3_conv': base_model.get_layer('conv3_block4_3_conv').output,
    'stage_4_conv': base_model.get_layer('conv4_block6_3_conv').output,  # Corrected layer name
    'stage_5_conv': base_model.get_layer('conv5_block3_3_conv').output,  # Corrected layer name
}
# Create models for each stage
models = {stage: Model(inputs=base_model.input, outputs=output) for stage, output in layers_to_extract.items()}

# %%
@contextlib.contextmanager
def suppress_stdout():
    """A context manager for suppressing stdout temporarily."""
    with open(os.devnull, 'w') as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

# %%
def preprocess_video(video_path, num_frames=30):
    # Capture video
    vidcap = cv2.VideoCapture(video_path)

    # Determine the total number of frames in the video
    total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the interval for frame sampling
    frame_interval = max(1, total_frames // num_frames)

    success, frame = vidcap.read()
    extracted_count = 0
    features_per_stage = {stage: [] for stage in layers_to_extract}

    while success and extracted_count < num_frames:
        # Check if the current frame is one of the frames to be extracted
        if total_frames > num_frames and (vidcap.get(cv2.CAP_PROP_POS_FRAMES) - 1) % frame_interval == 0:
            # Resize frame to match the input size expected by ResNet50
            resized_frame = cv2.resize(frame, (224, 224))  # Resize to 224x224

            # Preprocess frame
            img = image.img_to_array(resized_frame)
            img = np.expand_dims(img, axis=0)
            img = preprocess_input(img)

            # Extract and store features for each stage
            for stage, model in models.items():
                with suppress_stdout():
                    stage_features = model.predict(img)
                features_per_stage[stage].append(stage_features)

            extracted_count += 1

        success, frame = vidcap.read()

    # Stack features for 3D input
    stacked_features = {stage: np.stack(features, axis=0) for stage, features in features_per_stage.items()}

    return stacked_features

# %%
# Example usage
video_tensors = preprocess_video('AlgonautsVideos268_All_30fpsmax/0002_0-0-4-3146384004.mp4')

# %%
type(video_tensors)
# Out:
# dict

# %%
def process_batch(batch, input_folder, stage_folders):
    for filename in batch:
        video_id = filename[:4]

        # Check if the file for this video ID already exists in any stage folder
        if file_exists(video_id, stage_folders):
            print(f"Files for video ID {video_id} already exist. Skipping.")
            continue

        video_path = os.path.join(input_folder, filename)
        try:
            processed_data = preprocess_video(video_path)
            
            if not isinstance(processed_data, dict):
                raise ValueError(f"Unexpected data format for {filename}: {type(processed_data)}")

            video_id = filename[:4]
            for stage, features in processed_data.items():
                stage_folder = os.path.join(output_folder, stage)
                if not os.path.exists(stage_folder):
                    os.makedirs(stage_folder)
                    print(f"Created folder: {stage_folder}")

                output_file = os.path.join(stage_folder, f"{video_id}_{stage}.pkl")
                with open(output_file, 'wb') as file:
                    pickle.dump(features, file)
                    print(f"Saved file: {output_file}")

        except Exception as e:
            print(f"Error processing {filename}: {e}, data type: {type(processed_data)}")
            
        finally:
            # Explicitly delete large variables
            del processed_data
            # Call garbage collector
            gc.collect()


def file_exists(video_id, stage_folders):
    """Check if a file for the given video ID already exists in any of the stage folders."""
    for stage in stage_folders:
        filepath = os.path.join(stage_folders[stage], f"{video_id}_{stage}.pkl")
        if os.path.exists(filepath):
            return True
    return False

def process_and_save_videos(input_folder, output_folder, batch_size=90, id_range=None):
    # Ensure output folder exists and create a dictionary for stage folders
    stage_folders = {}
    stages = ['stage_1', 'stage_2', 'stage_3', 'stage_4', 'stage_5', 'final']
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for stage in stages:
        stage_folder = os.path.join(output_folder, stage)
        stage_folders[stage] = stage_folder
        if not os.path.exists(stage_folder):
            os.makedirs(stage_folder)

    # Get all MP4 files
    all_files = [f for f in os.listdir(input_folder) if f.endswith(".mp4")]

    # Filter files based on ID range if provided
    if id_range is not None:
        start_id, end_id = id_range
        all_files = [f for f in all_files if start_id <= f[:4] <= end_id]

    # Process in batches
    for i in range(0, len(all_files), batch_size):
        batch = all_files[i:i + batch_size]
        process_batch(batch, input_folder, stage_folders)  # Pass 'stage_folders' instead of 'output_folder'
        print(f"Processed batch {i // batch_size + 1}/{(len(all_files) - 1) // batch_size + 1}")

# %%
input_folder = video_folder  # Update with your input folder path
output_folder = 'preprocessed_videos_30frames_conv'  # Update with your output folder path
batch_size = 250   # Adjust based on your system's capability
id_range = ('0001', '1000')  # Process videos with IDs from 1000 to 2000
process_and_save_videos(input_folder, output_folder, batch_size, id_range)
# Out:
# Created folder: preprocessed_videos_30frames_conv/stage_2_conv
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0059_stage_2_conv.pkl
# Created folder: preprocessed_videos_30frames_conv/stage_3_conv
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0059_stage_3_conv.pkl
# Created folder: preprocessed_videos_30frames_conv/stage_4_conv
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0059_stage_4_conv.pkl
# Created folder: preprocessed_videos_30frames_conv/stage_5_conv
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0059_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0438_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0438_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0438_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0438_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0108_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0108_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0108_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0108_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0647_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0647_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0647_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0647_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0153_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0153_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0153_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0153_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0939_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0939_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0939_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0939_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0432_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0432_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0432_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0432_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0049_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0049_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0049_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0049_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0158_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0158_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0158_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0158_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0650_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0650_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0650_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0650_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0101_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0101_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0101_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0101_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0376_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0376_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0376_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0376_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0777_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0777_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0777_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0777_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0045_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0045_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0045_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0045_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0357_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0357_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0357_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0357_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0116_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0116_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0116_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0116_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0072_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0072_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0072_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0072_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0524_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0524_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0524_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0524_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0353_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0353_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0353_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0353_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0870_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0870_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0870_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0870_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0079_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0079_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0079_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0079_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0086_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0086_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0086_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0086_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0963_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0963_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0963_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0963_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0861_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0861_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0861_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0861_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0874_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0874_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0874_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0874_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0953_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0953_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0953_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0953_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0602_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0602_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0602_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0602_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0506_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0506_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0506_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0506_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0609_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0609_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0609_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0609_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0344_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0344_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0344_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0344_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0111_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0111_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0111_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0111_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0799_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0799_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0799_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0799_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0853_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0853_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0853_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0853_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0411_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0411_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0411_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0411_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0985_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0985_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0985_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0985_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0383_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0383_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0383_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0383_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0321_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0321_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0321_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0321_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0654_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0654_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0654_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0654_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0642_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0642_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0642_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0642_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0559_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0559_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0559_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0559_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0704_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0704_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0704_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0704_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0871_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0871_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0871_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0871_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0244_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0244_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0244_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0244_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0174_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0174_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0174_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0174_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0742_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0742_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0742_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0742_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0396_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0396_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0396_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0396_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0566_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0566_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0566_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0566_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0519_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0519_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0519_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0519_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0448_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0448_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0448_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0448_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0603_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0603_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0603_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0603_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0115_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0115_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0115_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0115_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0682_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0682_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0682_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0682_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0919_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0919_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0919_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0919_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0556_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0556_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0556_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0556_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0256_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0256_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0256_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0256_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0507_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0507_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0507_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0507_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0525_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0525_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0525_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0525_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0516_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0516_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0516_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0516_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0847_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0847_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0847_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0847_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0466_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0466_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0466_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0466_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0824_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0824_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0824_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0824_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0904_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0904_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0904_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0904_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0703_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0703_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0703_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0703_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0373_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0373_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0373_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0373_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0688_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0688_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0688_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0688_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0220_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0220_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0220_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0220_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0261_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0261_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0261_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0261_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0229_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0229_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0229_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0229_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0700_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0700_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0700_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0700_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0554_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0554_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0554_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0554_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0402_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0402_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0402_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0402_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0067_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0067_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0067_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0067_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0881_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0881_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0881_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0881_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0993_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0993_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0993_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0993_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0113_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0113_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0113_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0113_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0586_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0586_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0586_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0586_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0928_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0928_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0928_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0928_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0794_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0794_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0794_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0794_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0741_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0741_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0741_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0741_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0835_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0835_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0835_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0835_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0483_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0483_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0483_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0483_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0482_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0482_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0482_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0482_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0404_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0404_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0404_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0404_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0563_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0563_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0563_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0563_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0979_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0979_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0979_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0979_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0990_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0990_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0990_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0990_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0677_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0677_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0677_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0677_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0006_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0006_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0006_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0006_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0913_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0913_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0913_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0913_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0144_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0144_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0144_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0144_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0854_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0854_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0854_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0854_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0893_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0893_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0893_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0893_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0593_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0593_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0593_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0593_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0492_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0492_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0492_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0492_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0318_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0318_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0318_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0318_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0652_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0652_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0652_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0652_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0728_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0728_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0728_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0728_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0307_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0307_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0307_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0307_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0327_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0327_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0327_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0327_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0311_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0311_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0311_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0311_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0645_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0645_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0645_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0645_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0978_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0978_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0978_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0978_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0104_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0104_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0104_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0104_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0310_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0310_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0310_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0310_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0710_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0710_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0710_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0710_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0335_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0335_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0335_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0335_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0198_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0198_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0198_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0198_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0745_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0745_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0745_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0745_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0598_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0598_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0598_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0598_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0956_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0956_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0956_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0956_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0538_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0538_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0538_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0538_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0763_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0763_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0763_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0763_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0787_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0787_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0787_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0787_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0151_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0151_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0151_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0151_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0272_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0272_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0272_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0272_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0817_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0817_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0817_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0817_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0576_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0576_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0576_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0576_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0751_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0751_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0751_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0751_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0698_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0698_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0698_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0698_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0390_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0390_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0390_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0390_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0454_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0454_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0454_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0454_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0233_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0233_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0233_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0233_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0537_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0537_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0537_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0537_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0349_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0349_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0349_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0349_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0257_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0257_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0257_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0257_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0820_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0820_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0820_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0820_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0100_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0100_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0100_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0100_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0093_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0093_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0093_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0093_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0530_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0530_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0530_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0530_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0521_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0521_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0521_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0521_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0883_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0883_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0883_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0883_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0986_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0986_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0986_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0986_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0715_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0715_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0715_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0715_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0605_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0605_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0605_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0605_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0250_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0250_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0250_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0250_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0274_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0274_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0274_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0274_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0983_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0983_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0983_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0983_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0294_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0294_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0294_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0294_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0641_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0641_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0641_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0641_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0021_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0021_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0021_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0021_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0981_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0981_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0981_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0981_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0879_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0879_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0879_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0879_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0901_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0901_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0901_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0901_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0305_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0305_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0305_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0305_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0828_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0828_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0828_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0828_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0442_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0442_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0442_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0442_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0290_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0290_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0290_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0290_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0284_stage_2_conv.pkl
# ...
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0832_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0502_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0502_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0502_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0502_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0082_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0082_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0082_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0082_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0140_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0140_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0140_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0140_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0068_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0068_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0068_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0068_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0178_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0178_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0178_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0178_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0825_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0825_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0825_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0825_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0780_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0780_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0780_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0780_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0723_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0723_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0723_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0723_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0070_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0070_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0070_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0070_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0885_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0885_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0885_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0885_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0962_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0962_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0962_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0962_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0600_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0600_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0600_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0600_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0547_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0547_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0547_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0547_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0139_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0139_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0139_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0139_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0669_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0669_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0669_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0669_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0138_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0138_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0138_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0138_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0527_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0527_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0527_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0527_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0422_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0422_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0422_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0422_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0894_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0894_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0894_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0894_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0685_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0685_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0685_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0685_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0634_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0634_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0634_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0634_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0819_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0819_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0819_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0819_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0805_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0805_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0805_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0805_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0405_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0405_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0405_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0405_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0364_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0364_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0364_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0364_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0340_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0340_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0340_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0340_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0608_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0608_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0608_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0608_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0690_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0690_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0690_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0690_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0567_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0567_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0567_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0567_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0306_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0306_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0306_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0306_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0949_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0949_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0949_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0949_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0097_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0097_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0097_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0097_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0620_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0620_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0620_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0620_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0655_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0655_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0655_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0655_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0589_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0589_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0589_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0589_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0813_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0813_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0813_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0813_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0276_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0276_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0276_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0276_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0177_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0177_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0177_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0177_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0921_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0921_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0921_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0921_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0622_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0622_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0622_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0622_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0588_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0588_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0588_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0588_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0345_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0345_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0345_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0345_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0631_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0631_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0631_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0631_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0348_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0348_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0348_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0348_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0207_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0207_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0207_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0207_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0570_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0570_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0570_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0570_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0621_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0621_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0621_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0621_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0671_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0671_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0671_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0671_stage_5_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_2_conv/0005_stage_2_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_3_conv/0005_stage_3_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_4_conv/0005_stage_4_conv.pkl
# Saved file: preprocessed_videos_30frames_conv/stage_5_conv/0005_stage_5_conv.pkl

# %%
###--------------------------------------------------------------------------------------------------------###

# %%
def count_files_in_subfolders(parent_folder):
    subfolders = ['stage_1', 'stage_2', 'stage_3', 'stage_4', 'stage_5', 'final']
    file_counts = {}

    for subfolder in subfolders:
        path = os.path.join(parent_folder, subfolder)
        if os.path.exists(path):
            # Count only files, excluding subdirectories
            file_counts[subfolder] = sum([os.path.isfile(os.path.join(path, name)) for name in os.listdir(path)])
        else:
            print(f"Subfolder {subfolder} does not exist in {parent_folder}")
            file_counts[subfolder] = 0

    return file_counts

# Usage
parent_folder = 'preprocessed_videos'  
file_counts = count_files_in_subfolders(parent_folder)
for subfolder, count in file_counts.items():
    print(f"{subfolder}: {count} files")
# Out:
# Subfolder stage_1 does not exist in preprocessed_videos
# Subfolder stage_2 does not exist in preprocessed_videos
# Subfolder stage_3 does not exist in preprocessed_videos
# Subfolder stage_4 does not exist in preprocessed_videos
# Subfolder stage_5 does not exist in preprocessed_videos
# Subfolder final does not exist in preprocessed_videos
# stage_1: 0 files
# stage_2: 0 files
# stage_3: 0 files
# stage_4: 0 files
# stage_5: 0 files
# final: 0 files

# %%
# import os
# import pickle
# import numpy as np
# import random
# from sklearn.decomposition import PCA
# 
# def sample_and_apply_pca(stage_folders, repo_root, variance=0.999):
#     results = {}
#     for stage in stage_folders:
#         stage_folder = os.path.join(repo_root, stage)
#         if not os.path.exists(stage_folder):
#             print(f"Folder not found: {stage_folder}")
#             continue
# 
#         # Randomly sample three files
#         files = os.listdir(stage_folder)
#         sampled_files = random.sample(files, min(len(files), 3))
# 
#         for file in sampled_files:
#             file_path = os.path.join(stage_folder, file)
#             with open(file_path, 'rb') as f:
#                 tensor = pickle.load(f)
#                 original_shape = tensor.shape
#                 pca = PCA(n_components=variance)
#                 pca_tensor = pca.fit_transform(tensor.reshape(tensor.shape[0], -1))
#                 pca_shape = pca_tensor.shape
#                 results[file] = {'original_shape': original_shape, 'pca_shape': pca_shape, 'explained_variance': variance}
# 
#     return results
# 
# # Example usage
# stage_folders = ['stage_1', 'stage_2', 'stage_3', 'stage_4', 'stage_5', 'final']
# repo_root = 'preprocessed_videos'  # Replace with your repo root path
# 
# samples = sample_and_apply_pca(stage_folders, repo_root)
# for file, info in samples.items():
#     print(f"File: {file}, Original Shape: {info['original_shape']}, PCA Shape: {info['pca_shape']}, Variance: {info['explained_variance']}")
# Out:
# File: 0854_stage_1.pkl, Original Shape: (46, 1, 56, 56, 64), PCA Shape: (46, 45), Variance: 0.999
# File: 0432_stage_1.pkl, Original Shape: (45, 1, 56, 56, 64), PCA Shape: (45, 44), Variance: 0.999
# File: 0366_stage_1.pkl, Original Shape: (45, 1, 56, 56, 64), PCA Shape: (45, 40), Variance: 0.999
# File: 0703_stage_2.pkl, Original Shape: (45, 1, 56, 56, 256), PCA Shape: (45, 44), Variance: 0.999
# File: 0219_stage_2.pkl, Original Shape: (38, 1, 56, 56, 256), PCA Shape: (38, 37), Variance: 0.999
# File: 0317_stage_2.pkl, Original Shape: (45, 1, 56, 56, 256), PCA Shape: (45, 44), Variance: 0.999
# File: 0307_stage_3.pkl, Original Shape: (45, 1, 28, 28, 512), PCA Shape: (45, 44), Variance: 0.999
# File: 0256_stage_3.pkl, Original Shape: (45, 1, 28, 28, 512), PCA Shape: (45, 44), Variance: 0.999
# File: 0574_stage_3.pkl, Original Shape: (45, 1, 28, 28, 512), PCA Shape: (45, 44), Variance: 0.999
# File: 0709_stage_4.pkl, Original Shape: (36, 1, 14, 14, 1024), PCA Shape: (36, 35), Variance: 0.999
# File: 0207_stage_4.pkl, Original Shape: (36, 1, 14, 14, 1024), PCA Shape: (36, 35), Variance: 0.999
# File: 0797_stage_4.pkl, Original Shape: (45, 1, 14, 14, 1024), PCA Shape: (45, 44), Variance: 0.999
# File: 0055_stage_5.pkl, Original Shape: (45, 1, 7, 7, 2048), PCA Shape: (45, 42), Variance: 0.999
# File: 0395_stage_5.pkl, Original Shape: (37, 1, 7, 7, 2048), PCA Shape: (37, 36), Variance: 0.999
# File: 0528_stage_5.pkl, Original Shape: (46, 1, 7, 7, 2048), PCA Shape: (46, 45), Variance: 0.999
# File: 0811_final.pkl, Original Shape: (45, 1, 1000), PCA Shape: (45, 4), Variance: 0.999
# File: 0462_final.pkl, Original Shape: (36, 1, 1000), PCA Shape: (36, 33), Variance: 0.999
# File: 0175_final.pkl, Original Shape: (46, 1, 1000), PCA Shape: (46, 29), Variance: 0.999

# %%
# import cv2
# from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
# from keras.preprocessing import image
# import numpy as np
# 
# # Load the ResNet50 model pre-trained on ImageNet data
# model = ResNet50(weights='imagenet')
# 
# def classify_mid_frame(video_path):
#     # Capture the video
#     vidcap = cv2.VideoCapture(video_path)
# 
#     # Get the frame in the middle of the video
#     total_frames = vidcap.get(cv2.CAP_PROP_FRAME_COUNT)
#     mid_frame_index = int(total_frames / 2)
#     vidcap.set(cv2.CAP_PROP_POS_FRAMES, mid_frame_index)
#     success, mid_frame = vidcap.read()
#     
#     if not success:
#         return "Could not read the video file"
# 
#     # Convert the frame to a format suitable for ResNet50
#     img = cv2.cvtColor(mid_frame, cv2.COLOR_BGR2RGB)
#     img = cv2.resize(img, (224, 224))
#     x = image.img_to_array(img)
#     x = np.expand_dims(x, axis=0)
#     x = preprocess_input(x)
# 
#     # Classify the image
#     preds = model.predict(x)
#     return decode_predictions(preds, top=3)[0]

# %%
# # Example usage
# video_path = 'AlgonautsVideos268_All_30fpsmax/0006_0-1-9-9-8-6-5-9-4701998659.mp4'
# predictions = classify_mid_frame(video_patxh)
# print(predictions)
